# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
file_loc = "../WeatherPy/output_data/cities.csv"
weather_df = pd.read_csv(file_loc)
weather_df
# Out:
#      Unnamed: 0          City      Lat       Lng  Max Temp  Humidity  \
# 0             0     Mahajanga -15.7167   46.3167     84.20        84
# 1             1  Puerto Ayora  -0.7393  -90.3518     75.99        95
# 2             2     Jamestown  42.0970  -79.2353     37.40        65
# 3             3      Hermanus -34.4187   19.2345     63.00        92
# 4             4         Sitka  57.0531 -135.3300     39.20        93
# ..          ...           ...      ...       ...       ...       ...
# 570         570       Anjiang  27.3194  110.1031     51.98        91
# 571         571      Necochea -38.5473  -58.7368     57.99        94
# 572         572       Seymour  38.9592  -85.8903     55.00        66
# 573         573       Teguise  29.0605  -13.5640     62.60        77
# 574         574        Evensk  61.9500  159.2333     17.38        62
#
#      Cloudiness  Wind Speed Country        Date
# 0            20        3.44      MG  1617600771
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
locations = weather_df[["Lat", "Lng"]].astype(float)
humidity = weather_df["Humidity"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                                dissipating=False, max_intensity=100,
                                point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
weather2 = weather_df.loc[weather_df["Max Temp"] < 90]
weather3 = weather2.loc[weather2["Max Temp"] > 70]
weather4 = weather3.loc[weather3["Wind Speed"] < 20]
weather5 = weather4.loc[weather4["Cloudiness"] < 20]
hotel_df = weather5.reset_index()
hotel_df = hotel_df.drop(["index", "Unnamed: 0"], axis=1)
hotel_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Pitimbu  -7.4706  -34.8086     77.00        88           0
# 1            Busselton -33.6500  115.3333     84.00        51           2
# 2          Grand Gaube -20.0064   57.6608     84.99        70           5
# 3              Xai-Xai -25.0519   33.6442     74.50        67           0
# 4        Alice Springs -23.7000  133.8833     89.01        28           0
# 5           São Filipe  14.8961  -24.4956     73.27        71           0
# 6                 Fare -16.7000 -151.0167     82.42        74           5
# 7            Geraldton -28.7667  114.6000     80.60        57          12
# 8              Salalah  17.0151   54.0924     82.40        69           0
# 9             Sonāmura  23.4719   91.2664     86.00        42           1
# 10             Verāval  20.9000   70.3667     86.70        52           0
# 11              Faanui -16.4833 -151.7500     82.81        74          14
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df["Hotel Name"] = ""

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "rankby": "distance",
    "type": "lodging",
    "key": g_key,
}

for index, row in hotel_df.iterrows():
    
    coordinates = f"{row['Lat']}, {row['Lng']}"
    params["location"] = coordinates
    print(f"Retrieving Results for Index {index}: {coordinates}.")
    response = requests.get(base_url, params=params).json()
    
    results = response["results"]
    
    try:
        print(f"Closest hotel to {coordinates}: {results[0]['name']}.")
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Index 0: -7.4706, -34.8086.
# Closest hotel to -7.4706, -34.8086: Solar da Família Andrade - Pitimbu.
# Retrieving Results for Index 1: -33.65, 115.3333.
# Closest hotel to -33.65, 115.3333: Pearls Place.
# Retrieving Results for Index 2: -20.0064, 57.6608.
# Closest hotel to -20.0064, 57.6608: Talipot Lodge.
# Retrieving Results for Index 3: -25.0519, 33.6442.
# Closest hotel to -25.0519, 33.6442: Complexo da Familia.
# Retrieving Results for Index 4: -23.7, 133.8833.
# Closest hotel to -23.7, 133.8833: Aurora Alice Springs.
# Retrieving Results for Index 5: 14.8961, -24.4956.
# Closest hotel to 14.8961, -24.4956: Pensao ELIANE E CLARICE.
# Retrieving Results for Index 6: -16.7, -151.0167.
# Closest hotel to -16.7, -151.0167: HIRO.
# Retrieving Results for Index 7: -28.7667, 114.6.
# Closest hotel to -28.7667, 114.6: Ocean Centre Hotel.
# Retrieving Results for Index 8: 17.0151, 54.0924.
# ...

# %%
hotel_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Pitimbu  -7.4706  -34.8086     77.00        88           0
# 1      Busselton -33.6500  115.3333     84.00        51           2
# 2    Grand Gaube -20.0064   57.6608     84.99        70           5
# 3        Xai-Xai -25.0519   33.6442     74.50        67           0
# 4  Alice Springs -23.7000  133.8833     89.01        28           0
#
#    Wind Speed Country        Date                          Hotel Name
# 0        4.61      BR  1617600773  Solar da Família Andrade - Pitimbu
# 1        3.00      AU  1617600779                        Pearls Place
# 2        7.00      MU  1617600808                       Talipot Lodge
# 3        2.26      MZ  1617600811                 Complexo da Familia
# 4        9.22      AU  1617600815                Aurora Alice Springs

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=3,
    info_box_content=hotel_info
)
markers = gmaps.marker_layer(locations)
# Display figure
fig.add_layer(hotel_layer)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
